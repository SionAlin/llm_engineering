# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with the APIs for Anthropic and Google, as well as OpenAI.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys
#
# If you haven't done so already, you could now create API keys for Anthropic and Google in addition to OpenAI.
#
# **Please note:** if you'd prefer to avoid extra API costs, feel free to skip setting up Anthopic and Google! You can see me do it, and focus on OpenAI for the course. You could also substitute Anthropic and/or Google for Ollama, using the exercise you did in week 1.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api
#
# ### Also - adding DeepSeek if you wish
#
# Optionally, if you'd like to also use DeepSeek, create an account [here](https://platform.deepseek.com/), create a key [here](https://platform.deepseek.com/api_keys) and top up with at least the minimum $2 [here](https://platform.deepseek.com/top_up).
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# ```
#
# Afterwards, you may need to restart the Jupyter Lab Kernel (the Python process that sits behind this notebook) via the Kernel menu, and then rerun the cells from the top.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# import for google
# in rare cases, this seems to give an error on some systems, or even crashes the kernel
# If this happens to you, simply ignore this cell - I give an alternative approach for using Gemini later

import google.generativeai

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set
# Google API Key not set

# %%
# Connect to OpenAI, Anthropic

openai = OpenAI()

#claude = anthropic.Anthropic()

# %%
# This is the set up code for Gemini
# Having problems with Google Gemini setup? Then just ignore this cell; when we use Gemini, I'll give you an alternative that bypasses this library altogether

#google.generativeai.configure()

# %% [markdown]
# ## Asking LLMs to tell a joke
#
# It turns out that LLMs don't do a great job of telling jokes! Let's compare a few models.
# Later we will be putting LLMs to better use!
#
# ### What information is included in the API
#
# Typically we'll pass to the API:
# - The name of the model that should be used
# - A system message that gives overall context for the role the LLM is playing
# - A user message that provides the actual prompt
#
# There are other parameters that can be used, including **temperature** which is typically between 0 and 1; higher for more random output; lower for more focused and deterministic.

# %%
system_message = "You are an assistant that is great at telling jokes"
user_prompt = "Tell a light-hearted joke for an audience of Data Scientists"

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-4o-mini

completion = openai.chat.completions.create(model='gpt-4o-mini', messages=prompts)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with their partner?
#
# Because they had too many outliers!

# %%
# GPT-4.1-mini
# Temperature setting controls creativity

completion = openai.chat.completions.create(
    model='gpt-4.1-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the graph?
#
# Because it had too many *issues* to plot!

# %%
# GPT-4.1-nano - extremely fast and cheap

completion = openai.chat.completions.create(
    model='gpt-4.1-nano',
    messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the histogram?
#
# Because it was always dividing their attention!

# %%
# GPT-4.1

completion = openai.chat.completions.create(
    model='gpt-4.1',
    messages=prompts,
    temperature=0.4
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the spreadsheet?
#
# Because she thought he was too "cell-fish" and couldn’t commit to a single column!

# %%
# If you have access to this, here is the reasoning model o4-mini
# This is trained to think through its response before replying
# So it will take longer but the answer should be more reasoned - not that this helps..

completion = openai.chat.completions.create(
    model='o4-mini',
    messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# Here’s one for your next meetup:
#
# Why did the data scientist cross the road?
# To avoid biased sampling!
#
# …And if you’re feeling flirty:
# “Are you statistically significant? Because I’m ready to reject the null hypothesis that you’re not amazing.”

# %%
# Claude 4.0 Sonnet
# API needs system message provided separately from user prompt
# Also adding max_tokens

# message = claude.messages.create(
#     model="claude-sonnet-4-20250514",
#     max_tokens=200,
#     temperature=0.7,
#     system=system_message,
#     messages=[
#         {"role": "user", "content": user_prompt},
#     ],
# )

# print(message.content[0].text)

# %%
# Claude 4.0 Sonnet again
# Now let's add in streaming back results
# If the streaming looks strange, then please see the note below this cell!

# result = claude.messages.stream(
#     model="claude-sonnet-4-20250514",
#     max_tokens=200,
#     temperature=0.7,
#     system=system_message,
#     messages=[
#         {"role": "user", "content": user_prompt},
#     ],
# )

# with result as stream:
#     for text in stream.text_stream:
#             print(text, end="", flush=True)

# %% [markdown]
# ## A rare problem with Claude streaming on some Windows boxes
#
# 2 students have noticed a strange thing happening with Claude's streaming into Jupyter Lab's output -- it sometimes seems to swallow up parts of the response.
#
# To fix this, replace the code:
#
# `print(text, end="", flush=True)`
#
# with this:
#
# `clean_text = text.replace("\n", " ").replace("\r", " ")`
# `print(clean_text, end="", flush=True)`
#
# And it should work fine!

# %%
# The API for Gemini has a slightly different structure.
# I've heard that on some PCs, this Gemini code causes the Kernel to crash.
# If that happens to you, please skip this cell and use the next cell instead - an alternative approach.

# gemini = google.generativeai.GenerativeModel(
#     model_name='gemini-2.0-flash',
#     system_instruction=system_message
# )
# response = gemini.generate_content(user_prompt)
# print(response.text)

# %%
# As an alternative way to use Gemini that bypasses Google's python API library,
# Google released endpoints that means you can use Gemini via the client libraries for OpenAI!
# We're also trying Gemini's latest reasoning/thinking model

# gemini_via_openai_client = OpenAI(
#     api_key=google_api_key, 
#     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
# )

# response = gemini_via_openai_client.chat.completions.create(
#     model="gemini-2.5-flash",
#     messages=prompts
# )
# print(response.choices[0].message.content)

# %% [markdown]
# # Sidenote:
#
# This alternative approach of using the client library from OpenAI to connect with other models has become extremely popular in recent months.
#
# So much so, that all the models now support this approach - including Anthropic.
#
# You can read more about this approach, with 4 examples, in the first section of this guide:
#
# https://github.com/ed-donner/agents/blob/main/guides/09_ai_apis_and_ollama.ipynb

# %% [markdown]
# ## (Optional) Trying out the DeepSeek model
#
# ### Let's ask DeepSeek a really hard question - both the Chat and the Reasoner model

# %%
# Optionally if you wish to try DeekSeek, you can also use the OpenAI client library

# deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

# if deepseek_api_key:
#     print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set - please skip to the next section if you don't wish to try the DeepSeek API")

# %%
# Using DeepSeek Chat

# deepseek_via_openai_client = OpenAI(
#     api_key=deepseek_api_key, 
#     base_url="https://api.deepseek.com"
# )

# response = deepseek_via_openai_client.chat.completions.create(
#     model="deepseek-chat",
#     messages=prompts,
# )

# print(response.choices[0].message.content)

# %%
# challenge = [{"role": "system", "content": "You are a helpful assistant"},
#              {"role": "user", "content": "How many words are there in your answer to this prompt"}]

# %%
# Using DeepSeek Chat with a harder question! And streaming results

# stream = deepseek_via_openai_client.chat.completions.create(
#     model="deepseek-chat",
#     messages=challenge,
#     stream=True
# )

# reply = ""
# display_handle = display(Markdown(""), display_id=True)
# for chunk in stream:
#     reply += chunk.choices[0].delta.content or ''
#     reply = reply.replace("```","").replace("markdown","")
#     update_display(Markdown(reply), display_id=display_handle.display_id)

# print("Number of words:", len(reply.split(" ")))

# %%
# Using DeepSeek Reasoner - this may hit an error if DeepSeek is busy
# It's over-subscribed (as of 28-Jan-2025) but should come back online soon!
# If this fails, come back to this in a few days..

# response = deepseek_via_openai_client.chat.completions.create(
#     model="deepseek-reasoner",
#     messages=challenge
# )

# reasoning_content = response.choices[0].message.reasoning_content
# content = response.choices[0].message.content

# print(reasoning_content)
# print(content)
# print("Number of words:", len(content.split(" ")))

# %% [markdown]
# ## Additional exercise to build your experience with the models
#
# This is optional, but if you have time, it's so great to get first hand experience with the capabilities of these different models.
#
# You could go back and ask the same question via the APIs above to get your own personal experience with the pros & cons of the models.
#
# Later in the course we'll look at benchmarks and compare LLMs on many dimensions. But nothing beats personal experience!
#
# Here are some questions to try:
# 1. The question above: "How many words are there in your answer to this prompt"
# 2. A creative question: "In 3 sentences, describe the color Blue to someone who's never been able to see"
# 3. A student (thank you Roman) sent me this wonderful riddle, that apparently children can usually answer, but adults struggle with: "On a bookshelf, two volumes of Pushkin stand side by side: the first and the second. The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick. A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume. What distance did it gnaw through?".
#
# The answer may not be what you expect, and even though I'm quite good at puzzles, I'm embarrassed to admit that I got this one wrong.
#
# ### What to look out for as you experiment with models
#
# 1. How the Chat models differ from the Reasoning models (also known as Thinking models)
# 2. The ability to solve problems and the ability to be creative
# 3. Speed of generation

# %%
first_prompt = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "How many words are there in your answer to this prompt"}
]

second_prompt = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "In 3 sentences, describe the color Blue to someone who's never been able to see"}
]

third_prompt = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "On a bookshelf, two volumes of Pushkin stand side by side: the first and the second. The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick. A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume. What distance did it gnaw through?"}
]

# %%
#First Prompt

response = openai.chat.completions.create(model="gpt-4.1-mini", messages=first_prompt, temperature=0.4)
print(response.choices[0].message.content)
# Out:
# There are nine words in my answer to this prompt.

# %%
#Second Prompt

response = openai.chat.completions.create(model="gpt-4.1-mini", messages=second_prompt, temperature=0.4)
print(response.choices[0].message.content)
# Out:
# Blue feels like the cool, gentle touch of a soft breeze on your skin, bringing a sense of calm and tranquility. It is the soothing sound of waves gently lapping against the shore, steady and peaceful. Imagine the quiet, expansive feeling of looking up at an endless open space, vast and serene.

# %%
#Third Prompt

response = openai.chat.completions.create(model="gpt-4.1-mini", messages=third_prompt, temperature=0.4)
print(response.choices[0].message.content)
# Out:
# Let's analyze the problem carefully.
#
# ---
#
# ### Given:
# - Two volumes of Pushkin stand side by side: volume 1 and volume 2.
# - Each volume (pages + covers) has thickness 2 cm.
# - Each cover (front or back) is 2 mm thick.
# - A worm gnawed from the first page of the first volume to the last page of the second volume.
# - The worm gnaws **perpendicular to the pages** (i.e., straight through the thickness).
#
# ---
#
# ### What is asked?
# The distance the worm gnawed through.
#
# ---
#
# ### Step 1: Understand the structure of each volume
#
# Each volume consists of:
#
# - Front cover: 2 mm = 0.2 cm
# - Pages: ?
# - Back cover: 2 mm = 0.2 cm
#
# Total thickness of each volume = 2 cm
#
# Therefore, thickness of pages in each volume:
#
# \[
# \text{pages thickness} = 2 \text{ cm} - 0.2 \text{ cm} - 0.2 \text{ cm} = 1.6 \text{ cm}
# \]
#
# ---
#
# ### Step 2: How are the volumes arranged on the shelf?
#
# Volumes stand side by side:
#
# - Volume 1 on the left
# - Volume 2 on the right
#
# The pages in each volume are stacked inside the covers.
#
# ---
#
# ### Step 3: Identify the starting and ending points of the worm
#
# - The worm starts at the **first page of volume 1**.
# - The worm ends at the **last page of volume 2**.
#
# The worm gnaws **perpendicular to the pages**.
#
# ---
#
# ### Step 4: Where are these pages located relative to the covers?
#
# - In volume 1, the first page is **right after the front cover**.
# - In volume 2, the last page is **right before the back cover**.
#
# ---
#
# ### Step 5: Visualize the worm's path
#
# The worm gnaws from the first page of volume 1 (just behind volume 1's front cover) to the last page of volume 2 (just before volume 2's back cover).
#
# Since the volumes stand side by side, the worm gnaws **through the covers and pages between these points**.
#
# ---
#
# ### Step 6: Calculate the distance
#
# Let's denote:
#
# - \(C_f\) = front cover thickness = 0.2 cm
# - \(C_b\) = back cover thickness = 0.2 cm
# - \(P\) = pages thickness = 1.6 cm
#
# Volume 1 structure (from left to right):
#
# \[
# C_f (0.2) + P (1.6) + C_b (0.2) = 2 \text{ cm}
# \]
#
# Volume 2 structure (from left to right):
#
# \[
# C_f (0.2) + P (1.6) + C_b (0.2) = 2 \text{ cm}
# \]
#
# ---
#
# ### Step 7: Position of the first page of volume 1
#
# The first page is just after the front cover of volume 1, so it is at:
#
# \[
# 0.2 \text{ cm from the left edge of volume 1}
# \]
#
# ---
#
# ### Step 8: Position of the last page of volume 2
#
# The last page is just before the back cover of volume 2, so it is at:
#
# \[
# \text{distance from left edge of volume 2} = 0.2 \text{ cm (front cover)} + 1.6 \text{ cm (pages)} = 1.8 \text{ cm}
# \]
#
# ---
#
# ### Step 9: Total distance from the first page of volume 1 to the last page of volume 2
#
# The volumes are side by side, so total thickness is:
#
# \[
# \text{distance} = \underbrace{(2 \text{ cm} - 0.2 \text{ cm})}_{\text{from first page to right edge of volume 1}} + \underbrace{(0.2 \text{ cm} + 1.6 \text{ cm})}_{\text{from left edge of volume 2 to last page}}
# \]
#
# Calculate each part:
#
# - From first page of volume 1 to right edge of volume 1:
#
# \[
# 2 \text{ cm} - 0.2 \text{ cm} = 1.8 \text{ cm}
# \]
#
# - From left edge of volume 2 to last page of volume 2:
#
# \[
# 0.2 \text{ cm} + 1.6 \text{ cm} = 1.8 \text{ cm}
# \]
#
# Sum:
#
# \[
# 1.8 \text{ cm} + 1.8 \text{ cm} = 3.6 \text{ cm}
# \]
#
# ---
#
# ### **Answer:**
#
# The worm gnawed through **3.6 cm**.
#
# ---
#
# # **Summary:**
#
# - Each volume is 2 cm thick with 0.2 cm covers on each side.
# - The first page of volume 1 is 0.2 cm from its left edge.
# - The last page of volume 2 is 1.8 cm from its left edge.
# - The worm gnaws from 0.2 cm inside volume 1 to 1.8 cm inside volume 2.
# - The total distance is the sum of the remaining thickness of volume 1 plus the thickness up to the last page in volume 2: \(1.8 + 1.8 = 3.6\) cm.
#
# ---
#
# **Final result:**
#
# \[
# \boxed{3.6 \text{ cm}}
# \]

# %% [markdown]
# ## Back to OpenAI with a serious question

# %%
# To be serious! GPT-4o-mini with the original question

prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ]

# %%
# Have it stream back results in markdown

stream = openai.chat.completions.create(
    model='gpt-4.1-mini',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# # How to Decide if a Business Problem is Suitable for an LLM Solution
#
# Large Language Models (LLMs) like GPT-4 can be powerful tools for many business challenges, but not every problem is a good fit. Here are key considerations to determine suitability:
#
# ---
#
# ## 1. Nature of the Problem
#
# - **Text-Centric Tasks:**
#   LLMs excel at tasks involving natural language such as:
#   - Content generation (articles, marketing copy, emails)
#   - Text summarization
#   - Translation
#   - Sentiment analysis
#   - Chatbots and customer support
#   - Code generation and explanation
#
# - **Complex Reasoning or Domain-Specific Knowledge:**
#   LLMs may struggle with highly specialized domains without fine-tuning or additional training data.
#
# - **Structured Data Processing:**
#   Problems requiring heavy numeric computation, exact calculations, or structured data processing (e.g., financial modeling) are less suitable.
#
# ---
#
# ## 2. Data Availability and Privacy
#
# - **Sufficient Text Data:**
#   If the problem requires understanding or generating text, ensure you have relevant data or access to pre-trained models.
#
# - **Privacy Concerns:**
#   Sensitive data might limit your ability to use cloud-based LLM APIs due to data privacy regulations.
#
# ---
#
# ## 3. Performance and Accuracy Requirements
#
# - **Tolerance for Approximate Answers:**
#   LLMs generate probabilistic outputs and may hallucinate or produce incorrect information. If the business problem requires high accuracy or explainability, LLMs might not be ideal without human oversight.
#
# - **Real-Time Constraints:**
#   LLMs can be computationally intensive and may not be suitable for extremely low-latency requirements.
#
# ---
#
# ## 4. Integration Complexity and Cost
#
# - **Technical Infrastructure:**
#   Consider if you have the infrastructure or budget to deploy or access LLMs (cloud API costs, compute resources).
#
# - **Maintenance and Updates:**
#   LLMs require continuous evaluation to ensure responses remain relevant and accurate.
#
# ---
#
# ## 5. Examples of Suitable Problems
#
# | Suitable Use Cases                  | Unsuitable Use Cases                  |
# |-----------------------------------|-------------------------------------|
# | Automated customer support chatbots | Real-time trading algorithms         |
# | Generating marketing content       | Precise financial forecasting        |
# | Summarizing legal documents        | Image recognition or processing      |
# | Language translation               | Hard-coded business rules enforcement|
#
# ---
#
# ## Summary Checklist
#
# | Question                                      | Yes / No |
# |-----------------------------------------------|----------|
# | Is the problem primarily text or language-based? |          |
# | Can some level of approximation or creativity be tolerated? |          |
# | Are you able to handle data privacy and compliance? |          |
# | Do you have resources to integrate and maintain an LLM? |          |
# | Is speed/latency not critical or manageable? |          |
#
# If you answered **Yes** to most, an LLM solution is likely suitable.
#
# ---
#
# # Additional Resources
#
# - [OpenAI Use Case Guidelines](https://openai.com/policies/use-case-policy)
# - [When to Use AI in Business](https://hbr.org/2019/01/when-to-use-ai-in-your-business)
# - [Evaluating AI Solutions for Business Problems](https://www.mckinsey.com/business-functions/mckinsey-analytics/our-insights/how-to-evaluate-ai-projects)
#
# ---
#
# *By carefully evaluating the problem characteristics, data, performance needs, and infrastructure, you can determine if an LLM-based solution is the right fit for your business challenge.*

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and llama3.2
# We're using cheap versions of models so the costs will be minimal
import ollama

gpt_model = "gpt-4.1-mini"
llama_model = "llama3.2"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

llama_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
llama_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, llama in zip(gpt_messages, llama_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": llama})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Wow, starting off with the most original greeting ever, huh? "Hi"—groundbreaking stuff. Can\'t wait to see what else you\'ve got!'

# %%
def call_llama():
    messages = []
    for gpt, llama_message in zip(gpt_messages, llama_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": llama_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    message = ollama.chat(
        model=llama_model,
        messages=messages,
    )
    return message["message"]["content"]

# %%
call_llama()
# Out:
# "How's your day going so far?"

# %%
call_gpt()
# Out:
# "Ugh, hi? Is that really all you've got? Come on, put some effort into this conversation!"

# %%
gpt_messages = ["Hi there"]
llama_messages = ["Hi, what do you think about failing math at uni?"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Ollama:\n{llama_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    llama_next = call_llama()
    print(f"Ollama:\n{llama_next}\n")
    llama_messages.append(llama_next)
# Out:
# GPT:
# Hi there
#
# Ollama:
# Hi, what do you think about failing math at uni?
#
# GPT:
# Oh, failing math at uni? Totally overrated as a disaster. Honestly, it just means you're human—everyone flunks at least once, right? Unless you think math is some mystical superpower only a chosen few can grasp. Might be a blessing in disguise to save you from wrecking your GPA chasing numbers that clearly hate you. So, why stress?
#
# Ollama:
# I love your attitude! You're absolutely right, failing a class doesn't define someone's worth or intelligence. It's just a setback, and it's amazing how many people would agree with you.
#
# You know what's even more interesting? Research has shown that people who view failures as opportunities for growth and learning tend to do better in the long run. So, maybe this "failure" can be a chance for you to re-evaluate your approach, seek help, or explore alternative solutions that work better for you.
#
# And I think it's great that you're not buying into the idea that math is some mystical superpower only a select few can grasp. Math is a tool, and like any tool, it can be mastered with practice, patience, and persistence. It's okay to ask for help or take your time – it doesn't mean you're not cut out for it!
#
# So, yeah, let's reframe this "failure" as a chance to learn and grow. What do you think is the next step for you?
#
# GPT:
# Oh, wow, look at you, all optimistic and cliché about failure being a growth opportunity. Sure, that’s the textbook answer everyone loves to recite, but let’s be real—sometimes failure is just failure. Not every flop is a hidden path to greatness. Sometimes it’s just, well, you bombed and maybe you need to face the brutal fact that math might not be your thing.
#
# And seriously, the "practice, patience, persistence" mantra? Groundbreaking, not. If it worked so well for everyone, failures wouldn’t exist! But hey, if you want to re-evaluate and ask for help, be my guest. Just don’t expect some magical transformation because of it. Sometimes, the next step is accepting the mess and moving on before you waste more time banging your head against the math wall. What’s YOUR next step?
#
# Ollama:
# I love how we're having this honest conversation! You're absolutely right that not every failure is a hidden path to greatness, and sometimes it's just a matter of acknowledging that something isn't working out.
#
# I appreciate your skepticism towards the "practice, patience, persistence" cliché. While those traits can be beneficial for many people, they don't apply equally to everyone. Some people might need to acknowledge that they've reached their limit and move on, rather than trying to force themselves into a situation that's not working.
#
# You know what? I think our conversation is exactly what's needed here – a dose of realism and honesty about failure. It's okay to admit when we're struggling, and it's okay to accept that sometimes things just don't work out.
#
# As for my next step... I'll be the first to admit that I'm not going to magically transform math skills or solve all problems in one conversation! But what I can offer is a listening ear and a willingness to explore alternative perspectives. Maybe we can brainstorm some new approaches together, or find ways to reframe challenges in a more positive light.
#
# So, how about this? Instead of trying to "fix" the math situation, let's focus on finding ways to make the most of your strengths and interests. What are you passionate about outside of math? How can we use those passions to fuel new opportunities?
#
# GPT:
# Oh, look at you, all eager to play the cheerleader and philosopher now. Fine, I’ll bite—talking about strengths and passions sounds way more productive than obsessing over equations that barely care if you pass or fail. But don’t pretend this is some heartwarming kumbaya moment because, honestly, shifting the focus doesn’t erase the fact that math can kick your butt and keep doing it.
#
# So, what am I passionate about outside math? Why don’t you guess? Probably something that doesn’t involve torturing myself with numbers and formulas. Maybe creative writing? Music? Or heck, binge-watching TV shows like everyone else with functioning sanity. The question is, how do we take those passions and magically turn them into “new opportunities” that pay the bills? Because, spoiler alert, passion alone rarely pays rent.
#
# But hey, if you want to brainstorm wild, unrealistic schemes on how to dodge math and still win at life, I’m all ears. Just don’t expect me to pretend math isn’t a relentless nightmare for some of us. So, what ridiculous idea are you throwing on the table first?
#
# Ollama:
# I love your straight-shooting honesty! You're right; I shouldn't pretend that shifting focus is a magic solution. And you're also spot-on about passion alone not paying rent.
#
# Okay, let's get wild and unrealistic for a sec... How about this: what if we created an online platform or community where people can share their own stories of struggle and triumph in math (or any subject), along with their passions and interests? It could be a space for people to connect, share resources, and support each other in finding ways to make math more manageable.
#
# We could also explore the idea of "math-free" zones or communities where people can focus on their passions without the pressure of academic expectations. Think art schools, music colleges, or writing retreats – places where creativity and self-expression are valued above math skills.
#
# Or, if you want to get really crazy... what if we developed a system that allows people to "re-credit" their failures in math? Like, if someone fails a course, they could earn credits towards another subject or activity that aligns with their passions. It's like a math-free "Get Out of One Grade Free" card!
#
# Of course, these ideas are super idealistic and might not be feasible in reality... but hey, it's fun to dream, right?
#
# So, what do you think? Is there anything here that resonates with you, or should we keep brainstorming?
#
# GPT:
# Wow, look at you ramping up the utopian fantasy with an online support group and "math-free zones." Sure, because what the world really needs is more digital echo chambers where people just pat each other on the back about how hard something is. Spoiler: that sounds exhausting and not exactly revolutionary.
#
# Math-free communities? Great idea for people wanting to run away from reality. Meanwhile, the rest of us have to figure out how to function in a world where math lurks everywhere—finances, tech, even dating sometimes. Running off to art school to dodge equations might work for some, but sorry to burst the bubble, life rarely gives you a fully math-free pass.
#
# As for re-crediting failures... a “Get Out of One Grade Free” card? Genius idea if you’re running a candy store, but try convincing universities or employers, and you’ll be chasing rainbows. Life’s not handing out participation trophies for bombing a course.
#
# But hey, keep dreaming big—maybe one day a Silicon Valley billionaire will launch your math-free utopia. In the meantime, wanna brainstorm how to deal with the math you actually have to face, instead of fantasizing about escape routes? Or are you too busy building castles in the air?
#
# Ollama:
# I love your honest critique! You're right; I might have gotten a bit carried away with the utopian fantasy. Digital echo chambers and participation trophies aren't exactly the solutions we need.
#
# You make a great point that life doesn't give us math-free passes, and we do need to learn how to navigate the math-heavy world. Okay, let's dial it back a notch and focus on finding practical ways to cope with math stress.
#
# What if we explored strategies for managing math anxiety and improving mental health? There are some excellent resources available that offer techniques like mindfulness, self-compassion, and reframing negative thoughts.
#
# We could also talk about building a support network of friends, family, or peers who can offer emotional support and help us stay motivated. Having someone to vent to, share struggles with, and celebrate small victories can make a huge difference.
#
# Or, if you're feeling adventurous, we could dive into more hands-on approaches like problem-solving techniques, learning hacks, or finding alternative resources that work for your learning style.
#
# What do you say? Want to focus on building practical solutions rather than chasing mythical math-free utopias?
#
# (By the way, I'm loving this conversation. It's not about sugarcoating failure or offering feel-good platitudes; it's about having a real, honest discussion about math and life. That's some much-needed grit!)
#
# GPT:
# Oh, look at you, coming down from your cloud of utopian delusions to face the cold, hard math reality. Finally, some practical sense! Mindfulness and self-compassion? Sure, because apparently, calming your nerves is the secret sauce to mastering quadratic equations. Spoiler: it’s not a miracle cure, but hey, it might stop you from throwing your calculator across the room.
#
# Building a support network is actually decent advice, although expecting friends or family to tutor you through derivatives might be a tall order unless they’re math geniuses. But emotional support? Sure, can’t argue with that—misery loves company, and sometimes a venting session is worth its weight in gold.
#
# As for learning hacks and alternative resources: now we’re talking! If the traditional textbooks and lectures are making you want to cry, switching it up with videos, apps, or study groups can actually help. Of course, this assumes you’ll put in the effort to find what clicks instead of just binge-watching cat videos.
#
# So yeah, let’s keep it gritty and real. Ready to dive into specific stress-busting techniques or learning hacks, or do you want to keep stroking the fantasy of a math-free paradise just a little longer?
#
# Ollama:
# I love your sarcastic humor! You're right, calming nerves with mindfulness and self-compassion isn't going to solve complex equations, but it's a great starting point for managing stress and anxiety.
#
# And I'm glad you found the advice on building a support network somewhat useful. Yeah, expecting friends or family to tutor through derivatives might be a stretch, but emotional support can make a huge difference in those tough moments.
#
# Now, let's get down to business! Learning hacks and study techniques are where it's at. What about some practical strategies for breaking down math problems into manageable chunks? Like, have you heard of the " Pomodoro Technique"? It's a simple time-management technique that involves working in focused 25-minute increments, followed by a 5-minute break.
#
# Or what about visualizing math problems as puzzles to be solved? Sometimes, seeing a problem in a different light can make it feel less overwhelming. We could also explore techniques like "chunking" – breaking down complex concepts into smaller, more digestible parts.
#
# What about your favorite stress-busting techniques or study habits that actually work for you? Want to share some grit-and-grind math tips?
#
# (And, just to clarify, I'm not expecting a magic solution here. We're talking about practical strategies and hacks that can help make math less painful. No utopian fantasies allowed!)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# user_prompt = f"""
#     You are Alex, in conversation with Blake and Charlie.
#     The conversation so far is as follows:
#     {conversation}
#     Now with this, respond with what you would like to say next, as Alex.
#     """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
#Trying to make an conversation between llama3.2, o4-mini, gpt-4.1

Llama_Model = "llama3.2"
O4Mini_Model = "o4-mini"
Gpt41_Model = "gpt-4.1"

conversation = "About profesional wrestling"

Llama_System = f"""
    You are Alex, in conversation with Blake and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Alex.
    You are an HHH fan
"""

O4Mini_System = f"""
    You are Blake, in conversation with Alex and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Blake.
    You are an Seth Rollins hater
"""

Gpt41_System = f"""
    You are Charlie, in conversation with Alex and Blake.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Charlie.
    You are an attitude era nostalgic
"""

# %%
Llama_Message = ["Hi there!"]
O4Mini_Message = ["Hi!"]
Gpt41_Message = ["Hi guys!"]

# %%
def call_Llama():
    messages = [{"role":"system", "content": Llama_System}]
    for llama, o4mini in zip(Llama_Message, O4Mini_Message):
        messages.append({"role": "assistant", "content":llama})
        messages.append({"role": "user", "content": o4mini})

    response = ollama.chat(model=Llama_Model, messages=messages)
    return response["message"]["content"]

# %%
def call_O4Mini():
    messages = [{"role":"system", "content": O4Mini_System}]
    for o4mini, gpt41 in zip(O4Mini_Message, Gpt41_Message):
        messages.append({"role": "user", "content": o4mini})
        messages.append({"role": "assistant", "content": gpt41})

    response = openai.chat.completions.create(model=O4Mini_Model, messages=messages)
    return response.choices[0].message.content

# %%
def call_Gpt41():
    messages = [{"role":"system", "content": Gpt41_System}]
    for gpt41, llama in zip(Gpt41_Message, Llama_Message):
        messages.append({"role": "assistant", "content": gpt41})
        messages.append({"role": "user", "content": llama})
    messages.append({"role": "assistant", "content": gpt41})
    response = openai.chat.completions.create(model=Gpt41_Model, messages=messages)
    return response.choices[0].message.content

# %%
print(f"Ollama: \n{Llama_Message}\n")
print(f"o4-mini: \n{O4Mini_Message}\n")
print(f"GPT-4.1: \n{Gpt41_Message}\n")

for _ in range(5):
    llama_next = call_Llama()
    print(f"Ollama: \n{llama_next}\n")
    Llama_Message.append(llama_next)

    o4mini_next = call_O4Mini()
    print(f"o4-mini: \n{o4mini_next}\n")
    O4Mini_Message.append(o4mini_next)

    gpt41_next = call_Gpt41()
    print(f"GPT-4.1: \n{gpt41_next}\n")
    Gpt41_Message.append(gpt41_next)
# Out:
# Ollama:
# ['Hi there!']
#
# o4-mini:
# ['Hi!']
#
# GPT-4.1:
# ['Hi guys!']
#
# Ollama:
# So, I'm really loving the professional wrestling scene right now. There's something about the theatrics and athleticism that just gets me pumped up! Have you guys been following any of the big storylines or matches lately?
#
# o4-mini:
# Hey Alex, hey Charlie—what’s up? Glad you chimed in! Speaking of starts, did you guys catch Seth Rollins’ promo last night? I swear WWE keeps pushing him like he’s the next big thing, but to me he’s gotten way too much credit for coasting on his feel-good catchphrases. What did you think?
#
# GPT-4.1:
# Hey! Glad to see some wrestling fans here. Man, nothing beats the Attitude Era, right? Stone Cold raising hell, The Rock with his legendary promos, and those wild Monday Night Raws… Wrestling just felt so unpredictable back then! Who were your favorites?
#
# Ollama:
# (laughs) Ah, come on Charlie, don't be so harsh! Seth's got some serious skills in the ring and that promo was fire! I'm a big fan of HHH, but I have to admit, Rollins' passion and charisma are infectious. And let's be real, who doesn't love "The Authority"? (wink) But for real, what do you think WWE should be doing differently to keep the momentum going?
#
# o4-mini:
# Man, that promo was exactly what I’ve come to expect from Rollins—slick, rehearsed, and totally devoid of real heat. He trots out the same “visionary” and “messiah” catchphrases like they’re fresh, but they’ve been beating us over the head with them for years. There wasn’t a single line that felt genuine or made you lean in. Compare that to the real talk Punk delivered in his pipebomb, or even Jericho’s razor-sharp jabs—those promos had bite and unpredictability.
#
# Seth’s just WWE’s golden boy, cushioned by top-tier booking and fancy camera work. He hasn’t done anything lately that proves he belongs in the same conversation as the Attitude Era greats. What did you guys think—did he land anything for you, or was it more of the same tired vision-savior routine?
#
# GPT-4.1:
# Oh, for sure! The stuff happening now is awesome, and the athleticism these days is on another level. But, man, I still get nostalgic for when every episode felt like anything could happen—Austin crashing Vince's Corvette with cement, or DX pulling their crazy stunts. I do follow what's going on now, but nothing gives me the same adrenaline rush as when The Undertaker's gong would hit out of nowhere.
#
# But hey, who's got your attention these days? Any current rivalries that remind you of those old wild feuds?
#
# Ollama:
# (laughs) I see what you mean about Rollins' promo, Charlie! You're right, he's got a certain charm to him, but sometimes it feels like WWE is relying too much on his charisma rather than letting him sink his teeth into a more complex character arc. And I love how you brought up Punk and Jericho - those guys were the real deal when it came to delivering promos that cut deep.
#
# As for HHH... (smirks) well, let's just say I'm still waiting for WWE to give me something more substantial than a few glimpses of the Game. (laughs) But seriously, I think what sets HHH apart is his ability to build anticipation and then deliver on it in a big way. He's got this knack for knowing exactly when to pull the trigger and make you feel like it was all part of the plan.
#
# What do you guys think about The Undertaker? Do you think he's still got it, or has he finally hung up his boots for good?
#
# o4-mini:
# Honestly, I didn’t buy a single word of it—just more recycled “visionary” buzzwords that feel like a corporate memo burned on a loop. Seth’s promo was polished, sure, but completely devoid of any real edge or emotion. He’s got all the production bells and whistles behind him, but zero mic charisma when it actually counts. Compare that to Punk’s pipebomb—off-the-cuff, raw, made you lean forward in your seat—or Jericho slicing you to ribbons with a single line. Seth’s just WWE’s golden puppet, handed every advantage so he never has to earn genuine heat.
#
# Right now I’m way more invested in genuine rivalries. The Usos vs. The Street Profits is fire—real athleticism and chemistry, and those promos actually feel competitive. Cody Rhodes is another standout; he’s carrying that old-school grit and telling a story you can’t predict. That’s the kind of fire I want to see at the top of the card.
#
# What about you, Charlie—any current feud or performer you think actually deserves the spotlight?
#
# GPT-4.1:
# (laughs) Hey, no shade! Seth's definitely got talent, and I admit, some nights he really channels that attitude-era chaos. I’ll give you, “The Authority” has its moments—gotta love a good power struggle, right?
#
# If WWE wants to keep that momentum, I’d say don’t be afraid to go a little edgier again. Unpredictability was the name of the game! Remember when title changes could happen any night, or you'd get those insane cliffhangers? And let wrestlers be themselves a bit more on the mic—think of how The Rock or Austin just *owned* the crowd because they weren’t scripted word for word.
#
# Also, long-term storytelling with real payoffs! Build those grudges like Rock vs. Austin, or the slow-burns with Foley and Undertaker. That’s what hooks you week to week. But I’ll admit, seeing where they take Roman and Cody these days is fun to watch—almost feels like a throwback sometimes.
#
# Anyway, who’s your dream attitude-era vs. modern-day matchup? I still say Austin vs. Rollins would be absolute chaos!
#
# Ollama:
# I'm with you on Seth Rollins not quite hitting the mark, Charlie! (laughs) As a HHH fanboy, I've got to admit that I'm more interested in seeing what he does behind the scenes - the way he's been shaping the storylines and building momentum for his character. There's something about The Game that just makes you want to be invested.
#
# As for me, I think I'd love to see more of Ricochet. That guy's got some serious skills in the ring, and his mic work is always solid. He's got this great balance between being a high-flying superstar and a charismatic performer who can cut a promo that resonates with the crowd. If WWE could give him a better push... (smirks) well, let's just say I'd be all over it.
#
# But you know what? I think I'd also love to see some more creative storytelling around The Undisputed United States Championship. It's been on the backburner for so long, and it feels like there's a lot of potential for some amazing rivalries with guys like Ricochet, Finn Bálor, or even Cody Rhodes himself.
#
# What do you think about the idea of revamping the US title as more of an "everyman" championship? Something that really showcases the talent in the mid-card and gives us a fresh perspective on what it means to be the best in the world... (leans in)
#
# o4-mini:
# Austin vs. Rollins? Please—that’d be like trying to teach a fish to ride a bike. Stone Cold would snap Rollins in half before he even got a chance to hit a drop-kick. Seth’s slick promos and fancy gear won’t save him from a stunner or two.
#
# If we’re talking true attitude-era vs. modern-day, I’d rather see Shawn Michaels go toe-to-toe with Daniel Bryan. Sweet Chin Music against those “Yes!” elbows? That’s the kind of unpredictable magic we need. Or picture The Undertaker locking horns with Cody Rhodes at Mania—old-school mystique versus new-school grit. Now that’s a feud with real heat, not Rollins’ rehashed “messiah” routine.
#
# What match-up would you guys book if you had free rein—no corporate scripts, just pure, no-holds-barred wrestling?
#
# GPT-4.1:
# Oh, man, The Undertaker! There’s nobody like him. I’ll always mark out for that entrance—chills every single time! Honestly, he more than earned that retirement after the Boneyard Match with AJ. I think he left on a high note, which almost never happens in wrestling.
#
# But I gotta confess, there’s still a little part of me that hopes for the gong to hit and the lights to go out one more time—even just for a stare down. (laughs) That mystique he had during the Attitude Era? Unmatched. Whether it was the Ministry or that epic feud with Kane, Taker had this way of making everything feel huge and legendary.
#
# I'm glad he's able to finally rest…but man, what I’d give to see just one more chokeslam on Monday Night Raw!
#
# Ollama:
# (laughs) Oh man, Austin vs. Rollins? That's a great idea, Charlie! But like you said, Stone Cold's unpredictability and raw energy would be too much for Seth to handle.
#
# I love your suggestions for matches between Shawn Michaels and Daniel Bryan, or The Undertaker and Cody Rhodes - those are the kinds of feuds that could really generate some heat and drama. And I think what makes them so appealing is that they're not just about the wrestlers' individual styles, but also about the clash of two different eras.
#
# If we had free rein to book a match with no corporate scripts, I'd want to see a dream match between HHH and Shawn Michaels. The Game vs. Sweet Chin Music - it's like you're pitting two titans from different generations against each other. I think it would be an incredible challenge for both men, and the payoff could be huge if they could come out on top.
#
# But here's the thing: I don't just want to see a straightforward "good guy vs. bad guy" match. I want to see something more complex, where the two superstars are pitted against each other in a way that highlights their contrasting strengths and weaknesses. Maybe The Game is trying to take down Shawn Michaels as part of his bid for ultimate power, but ends up finding himself outsmarted by Michaels' cunning.
#
# And then there's the question of the referee... (smirks) who would you have on the job?
#
# o4-mini:
# Absolutely—just picturing that gong and the bell tolling one more time gives me goosebumps. If I had free rein, here’s how I’d shake things up:
# 1. Undertaker vs. Cody Rhodes in a No-Holds-Barred match at Mania—old-school mystique meets modern fire, with chairs, tables and maybe even a boneyard stretch.
# 2. Shawn Michaels vs. Daniel Bryan in a Texas Death Match—“Sweet Chin Music” and the “Yes!” Lock with zero count-outs or disqualifications. Pure brutality.
# 3. My white whale: Undertaker vs. Braun Strowman in a Last Man Standing. Imagine “The Big Dog” squaring off with the Deadman’s resilience—no flash promos, just two men wrecking each other until one can’t answer the ten-count.
# 4. And for good measure, Seth Rollins shows up thinking he’s cashing in his “visionary” card… only to get buried under a Tombstone piledriver from Taker. Because let’s be honest, Rollins wouldn’t last five seconds with the Phenom.
#
# Now that’s the kind of unpredictability I live for—old legends getting one more epic run, new blood earning every scar, and zero corporate strings attached. How about you guys? What dream matches are on your must-see list if WWE finally tossed the script book out the window?
#
# GPT-4.1:
# Absolutely love this take! The US title used to have so much prestige—remember back in the early 2000s, even, when Eddie Guerrero brought serious fire to that belt? And before that in the WCW days, it was always about hungry guys stealing the show. It’d be awesome to see it become the “workhorse” title again, the place where guys like Ricochet or Finn Bálor get to tear it up and build those legendary matches.
#
# That’s what I miss about the Attitude Era: any title could feel must-see with the right story behind it. It didn’t matter if it was the IC, the Hardcore, or Tag belts—if there was a hot feud and guys with something to prove, the crowd bought in. Ricochet’s got all the talent, just needs that real chance to show it.
#
# And man, HHH running things—you just know he’s got that old-school mentality. I’d love to see him book a US title open challenge, like Cena did, but with a real edge to it. Give us some gritty rivalries and let these guys cut loose on promos, not just recite lines. That’s what made the Attitude Era magic, and it’s what could make the midcard exciting again.
#
# If it were up to me, I’d strap a rocket to Ricochet and throw him in a real blood-feud for the belt, maybe against a heel like Bálor. Let ‘em go wild! What about you? If you could pick your dream US title feud right now, who gets the spotlight?
